# %%
from instrumentdatabaseapi import instrumentdatabaseapi as API

repo = API.Repository(local_repo=".")

# %%
print(repo)
# Out:
# URL: https://github.com/PaNOSC-ViNYL/instrument_database.git
# local_dir: ./

# %% [markdown]
# Load the instrument configuration providing:
#  - name of the institute
#  - name of the instrument
#  - version of the instrument description (HEAD is the most recent)
#  - name of the simulation program

# %%
#help(repo)

# %%
repo.ls_institutes()
# Out:
#  - test_institute
#  - ILL

# %%
repo.ls_instruments("ILL")
instrument_name="Panther"
#instrument_name="ThALES"
# Out:
# Available instruments for ILL:
#  -  ILL/Panther
#  -  ILL/D22
#  -  ILL/ThALES

# %%
repo.ls_versions("ILL",instrument_name)
# Out:
# Available versions for instrument Panther:
#  -  HEAD

# %%
repo.ls_simulation_programs("ILL",instrument_name,"HEAD")
# Out:
# Instrument Panther from institute ILL is implemented with the following programs:
#  -  mcstas

# %%
repo.ls_flavours("ILL",instrument_name,"HEAD","mcstas")
# Out:
# Available flavours for instrument Panther:
#  -  None
#  -  nosection

# %%
flavour="nosection"
myinstrument = repo.load("ILL", instrument_name, "HEAD", "mcstas", flavour, dep=False)
# Out:
# L_bc5_fermi before BC3 =  1.6
# 7.7311000000000005

# %%
myinstrument.list_calculators()
# Out:
# - Instrument: Panther -
# Calculators:
# OriginCalc

# %%
print(myinstrument)
# Out:
# ######## Instrument Panther
# - Instrument: Panther -
# Calculators:
# OriginCalc
# - ParametersCollection object -
#   Master Parameters
#   energy                                   [millielectron_volt]  Initial neutron energy
#
#    OriginCalc
#     - Parameters object -
#    mono_index                          -1                              Monochromator index, automatically based on the energy if set to -1   L[-1, 5]
#    a2                                  0          [degree]             Angle between beam reflected by monochromator and incident beam   L[36.0 degree, 58.97 degree](0 degree)
#    mono_rv                             -1                              Monochromator vertical focusing: internally calculated if value is zero
#    mono_rh                             -1                              Monochromator horizontal focusing: internally calculated if value is zero
#    chopper_rpm                         0                               Fermi chopper speed   L[6000, 30000](0)
#    chopper_ratio                       1                                  L[1, 2]
#    Ei                                  15         [millielectron_volt]  Initial neutron energy   L[7.5 millielectron_volt, 130 millielectron_volt]
#    dE                                  0          [millielectron_volt]  Initial neutron energy dispertion
#    dch                                 0                               Heavy slit horizontal aperture: if zero it is automatically calculated
#    Efoc                                0          [millielectron_volt]  Focusing energy
#    before_sample_slit_width            0.2        [meter]              Horizontal width of the slit opening
#    before_sample_slit_height           0.2        [meter]              Vertical height of the slit opening
#    sample_rotation                     0          [degree]             sample table rotation angle
#    sample_width                        0.0        [meter]              width of the sample if shape is box
#    sample_height                       0.0        [meter]              height of the sample if shape is box or cylinder
#    sample_depth                        0.0        [meter]              depth of the sample if shape is box
#    sample_radius                       0.0        [meter]              radius of the sample if shape is sphere or cylinder
#    sample_thickness                    0.0        [meter]              thickness of the sample if it is hollow
#
# ############

# %%
# setting the base directory for the simulation output
basedir = "/tmp/"+instrument_name+"/"
myinstrument.set_instrument_base_dir(basedir)

# %%
myinstrument.master
# Out:
#  - Parameters object -
# energy                                   [millielectron_volt]  Initial neutron energy

# %%
import pint
ureg = pint.get_application_registry()

if instrument_name == "ThALES":
    myinstrument.master["a2"] = myinstrument.energy_to_angle(4.98 * ureg.meV)
    myinstrument.master["a4"] = 60 * ureg.degree
    myinstrument.master["a6"] = myinstrument.master["a2"].pint_value
if instrument_name == "Panther":
    myinstrument.master["energy"]=19 * ureg.meV

# %%
myinstrument.samples
# Out:
# ['None', 'vanadium', 'H2O', 'D2O', 'sqw']

# %%
myinstrument.set_sample_by_name("vanadium")
# Out:
# SPLIT 70 COMPONENT sqw = Isotropic_Sqw(
#   Sqw_coh = 0, // [str]
#   Sqw_inc = 0, // [str]
#   radius = sample_radius, // [m]
#   thickness = sample_thickness, // [m]
#   xwidth = sample_width, // [m]
#   yheight = sample_height, // [m]
#   verbose = 2, // [1]
#   d_phi = 43.60281897270362, // [deg]
#   rho = 0.07232226802632531, // [AA-3]
#   sigma_abs = 5.08, // [barns]
#   sigma_coh = 0, // [barns]
#   sigma_inc = 4.935, // [barns]
#   p_interact = 1 // [1]
# )
# AT (0, 0, 0) RELATIVE sample_arm

# %%
myinstrument.sample_cylinder_shape(0.005, 0.01)

# %%
myinstrument.sim_neutrons(5e6)
myinstrument.set_seed(654321)

# %% [markdown]
# ### Diagnostics of the beam for one calculator

# %%
mycalc = myinstrument.calculators["OriginCalc"]
mycalc.backengine()
#myinstrument.run()
print(mycalc.output)
# Out:
# INFO: Using directory: "/tmp/Panther/OriginCalc_3"
# INFO: Regenerating c-file: OriginCalc.c
# Info:    Defining SPLIT from sqw=Isotropic_Sqw() to END in instrument OriginCalc
# CFLAGS=
#         INFO: Recompiling: ./OriginCalc.out
# mccode-r.c: In function ‘sighandler’:
# mccode-r.c:3825:5: warning: implicit declaration of function ‘kill’; did you mean ‘ceill’? [-Wimplicit-function-declaration]
# INFO: ===
# lambda = 2.07
# Selecting monochromator...mono_d = 3.3550
# a2 = 36.03
# mono_d = 3.3550
# a2 = 36.03
# mono_index = 1
# dch = 0.08
# Chopper_rpm = 9114.77
# Neutron velocity: 1906.55
# E_focus: 0.00
# [OriginCalc] Initialize
# Opening input file '/usr/local/mcstas/2.7.1/tools/Python/mcrun/../mccodelib/../../../data/Al2O3_sapphire.trm' (Table_Read_Offset)
# DiskChopper: BC1: frequency=50.6376 [Hz] 3038.26 [rpm], time frame=0.00329136 [s] phase=0 [deg]
#              6 slits, angle=41.3346 [deg] height=0.175 [m], width=0.15 [m] at radius=0.2125 [m]
# Monochromator_curved: component Monochromator Q=1.87 Angs-1 (DM=3.355 Angs)
#             horizontal: 11 blades focusing with RH=10.1 [m]
#             vertical:   15 blades focusing with RV=0.0147 [m]
# FermiChopper: fermi_chopper: Frequency nu=151.913 [Hz] 9114.77 [rpm], time frame=0.0131654 [s] phase=0 [deg]
# Isotropic_Sqw: sqw: is a cylinder: radius=0.005000 thickness=0.000000 height=0.010000 [J Comp Phys 228 (2009) 5251]
# Isotropic_Sqw: sqw: Using Isotropic elastic incoherent scattering (sigma=4.935 [barns])
# Isotropic_Sqw: sqw: Focusing can only apply for single
#                scattering. Setting to order=1.
# Warning: Number of events 19460 reaching SPLIT position Component[23] sqw=Isotropic_Sqw()
#          is probably too low. Increase Ncount.
#
# Save [OriginCalc]
# FermiChopper: fermi_chopper
#               Mean velocity     v     = 1908.1 [m/s]
#               Mean wavelength   lambda= 2.07328 [Angs]
#               Mean energy       omega = 19.0309 [meV]
#               Mean arrival time t     = 0.00403339 [s]
#               Mean phase              = -138.531 [deg] (set automatically)
#               Slit pack divergence    = 2.98867 [deg] (full width)
#               Opening time      dt    = 0.00313114 [s]
#               Intensity reaching FC   = 7.57159e+06 [n/s]
#               Intensity passing  FC   = 42019.9 [n/s]
# FermiChopper: fermi_chopper: Lost events anaylsis
#               Already inside:            0
#               By Top/Bottom of cylinder: 0
#               At cylinder entrance:      20409
#               Hit cyl. entrance sides:   0
#               Can't prop. to slit pack:  73
#               At slit pack entrance:     2767
#               On absorbing slit coating: 10329
#               Exiting slit pack:         0
#               Too many iterations:       0
#               Prop. in wrong direction : 0
#               Mad neutron (no control):  0
#               At cylinder exit:          2
# Warning:      Can not reach slit wall:   0
# Warning:      Can not reach slit output: 607
# Events:   "detector_TOF_dat_list.p.th.y.t"
#
# Finally [OriginCalc: /tmp/Panther/OriginCalc_3]. Time: 7 [s]
# Isotropic_Sqw: sqw: Scattering fraction=0.227936 of incoming intensity
#                Absorption fraction           =0.543815
#                Single   scattering intensity =186.269 (coh=0 inc=186.269)
#                Multiple scattering intensity =0
# INFO: Placing instr file copy OriginCalc.instr in dataset /tmp/Panther/OriginCalc_3
# loading system configuration
# loading user configuration from /home/shervin/.mcstas/2.7.1/mccode_config.json
#
# Data collection:
# key - mapping
#
# OriginCalc_data - <class 'dict'>: dict_keys(['data'])

# %%
#mycalc = myinstrument.calculators["OriginCalc"]
#mycalc = myinstrument.calculators["SampleCalc"]
#mycalc.input = myinstrument.calculators["OriginCalc"].output
mycalc.show_diagram()

# %%
mycalc.show_diagram(analysis=True)

# %%
import mcstasscript as ms

# %%
diag = ms.Diagnostics(mycalc)
diag.settings(ncount=1e7, suppress_output=True)
diag.show_settings()
diag.clear_points()

elements = []
if len(elements) == 0:
    for component in diag.instr.component_list:
            continue
        elements.append(component.name)

print(elements)

for element in elements:
    diag.add_point(after=element)
    #diag.add_point(before=element)

if mycalc.name == "SampleCalc":
    diag.clear_points()
    diag.add_point(after="Vin")
    diag.add_point(before="sqw")
    diag.add_point(after="Sample_Out")
    diag.add_point(before="after_sample_slit")
    diag.add_point(after="after_sample_slit")

print(diag)
# Out:
# Instrument settings:
#   ncount:           1.00e+07
#   seed:             654321
#   output_path:      /tmp/Panther/OriginCalc
#   run_path:         ./
#   package_path:     /usr/local/mcstas/2.7.1/
#   executable_path:  /usr/local/mcstas/2.7.1//bin/
#   executable:       mcrun
#   force_compile:    True
# ['HCS', 'B', 'sapphire', 'BC1', 'diaphragm1', 'BC2', 'BC3', 'BC4', 'BC5', 'heavy_diaphragm', 'Monochromator', 'BS', 'fermi_chopper', 'before_sample_diaphragm', 'sqw', 'PSD_TOF']
# Instrument diagnostics for: OriginCalc
# Diagnostics points:
#   Diagnostics point after:  HCS                       - rays: 50000
#   Diagnostics point after:  B                         - rays: 50000
#   Diagnostics point after:  sapphire                  - rays: 50000
#   Diagnostics point after:  BC1                       - rays: 50000
#   Diagnostics point after:  diaphragm1                - rays: 50000
#   Diagnostics point after:  BC2                       - rays: 50000
#   Diagnostics point after:  BC3                       - rays: 50000
#   Diagnostics point after:  BC4                       - rays: 50000
#   Diagnostics point after:  BC5                       - rays: 50000
#   Diagnostics point after:  heavy_diaphragm           - rays: 50000
#   Diagnostics point after:  Monochromator             - rays: 50000
#   Diagnostics point after:  BS                        - rays: 50000
#   Diagnostics point after:  fermi_chopper             - rays: 50000
#   Diagnostics point after:  before_sample_diaphragm   - rays: 50000
#   Diagnostics point after:  sqw                       - rays: 50000
#   Diagnostics point after:  PSD_TOF                   - rays: 50000
# Views:
#   No views yet
# Does not yet contain simulated data

# %%
diag.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-831e852f5c83> in <module>
# ----> 1 diag.run()
#
# /opt/panosc/McStasScript/mcstasscript/instrument_diagnostics/beam_diagnostics.py in run(self)
#     377         self.data = self.instr.backengine()
#     378
# --> 379         self.read_data()
#     380
#     381     def read_data(self):
#
# /opt/panosc/McStasScript/mcstasscript/instrument_diagnostics/beam_diagnostics.py in read_data(self)
#     387
#     388         for point in self.ordered_point_list:
# --> 389             event_data = name_search(point.filename, self.data)
#     390             point.set_recorded_rays(event_data.metadata.total_N)
#     391             plotter = event_plotter.EventPlotter(point.filename, event_data,
#
# /opt/panosc/McStasScript/mcstasscript/interface/functions.py in name_search(name, data_list)
#      51         raise NameError("No dataset with name: \""
#      52                         + name
# ---> 53                         + "\" found.")
#      54
#      55     if len(list_result) == 1:
#
# NameError: No dataset with name: "Diag_after_BS" found.

# %%
diag.clear_views()
#diag.add_view("t")
diag.add_view("x", bins=50, limits=[-0.04,0.04])
diag.add_view("y", bins=50, same_scale=False, limits=[-0.07,0.07])
diag.add_view("x","y",bins=[30,30])
diag.add_view("e", same_scale=True)

# %%
diag.plot()

# %%
mycalc.show_instrument()

# %%
ms.make_sub_plot(data_empty[55:59])

# %%
ms.make_sub_plot(data_empty[65:69])

# %%
# %matplotlib widget
import mcstasscript.jb_interface as ms_widget
ms_widget.show(data_empty)

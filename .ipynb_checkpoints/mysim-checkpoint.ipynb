# %%
from instrumentdatabaseapi import instrumentdatabaseapi as API

repo = API.Repository(local_repo=".")

# %%
print(repo)
# Out:
# URL: https://github.com/PaNOSC-ViNYL/instrument_database.git
# local_dir: ./

# %%
myinstrument = repo.load("ILL", "ThALES", "HEAD", "mcstas", dep=False)

# %%
#print(myinstrument)
myThALES = myinstrument.calculators["ThALES"]
# myThALES.show_components()

import pint

ureg = pint.get_application_registry()

a2 = myinstrument.parameters["ThALES"]["a2"]
a2.energy = 4.98 * ureg.meV

basedir = "/tmp/ThALES_scan/"
myinstrument.set_instrument_base_dir(basedir)

a4 = myinstrument.parameters["ThALES"]["a4"]
a3 = myinstrument.parameters["ThALES"]["a3"]
a3.value = 0 * ureg.degree
a4.value = 60 * ureg.degree

a6 = myinstrument.parameters["ThALES"]["a6"]

dE = 0.05

energy = 4.98

myThALES.settings(ncount=10000000)

# %%
#myThALES.show_diagram()
myThALES.show_diagram()

# %%
myThALES.show_components()
# Out:
# Origin  Progress_bar
#   AT      (0, 0, 0) ABSOLUTE
# HCS  Source_simple
#   AT      (0,  0,  0) RELATIVE Origin
# H5  Arm
#   AT      (0, 0, 2.155) RELATIVE HCS
# H5_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H5_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H5_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H5_1  Guide_gravity
#   AT      (0, 0, 0) RELATIVE H5
# H5_1a_DEBUG  Monitor_nD
#   AT      (0, 0, 1.0) RELATIVE PREVIOUS
# H5_1a_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H5_1a_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H5_1b  Guide_gravity
#   AT      (0, 0, 1.0) RELATIVE H5_1
# H5_1b_DEBUG  Monitor_nD
#   AT      (0, 0, 1.775) RELATIVE PREVIOUS
# H5_1b_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H5_1b_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H53_A  Arm
#   AT      (0, 0, 1.8059999999999998) RELATIVE H5_1b
# H53_2a  Guide_gravity
#   AT      (0, 0, 0) RELATIVE H53_A
# H53_2b  Guide_gravity
#   AT      (0, 0, 2.317) RELATIVE H53_2a
# H53_B  Arm
#   AT      (0, 0, 0.844) RELATIVE H53_2b
# H53_3  Guide_gravity
#   AT      (0, 0, 0) RELATIVE H53_B
# H53_4  Guide_gravity
#   AT      (0, 0, 0.501) RELATIVE H53_3
# H53_5  Guide_gravity
#   AT      (0, 0, 0.501) RELATIVE H53_4
# H53_C  Arm
#   AT      (0, 0, 5.9508) RELATIVE H53_5
# H53_6  Guide_gravity
#   AT      (0, 0, 0) RELATIVE H53_C
# H53_D  Arm
#   AT      (0, 0, 2.4414999999999996) RELATIVE H53_6
# H53_D_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H53_D_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H53_D_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H53_7  Guide_tapering
#   AT      (0, 0, 0) RELATIVE H53_D
# H53_7out  Arm
#   AT      (0, 0, 2.4915) RELATIVE H53_7
# H53_7_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H53_7_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# H53_7_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# slit_A  Slit
#   AT      (0, 0, 2.7914999999999996) RELATIVE H53_7
# slit_A_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# slit_A_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# slit_A_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# Monochromator_Arm  Arm
#   AT      (0, 0, 2) RELATIVE slit_A
# mono_in_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# mono_in_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# mono_in_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# Monochromator  Monochromator_curved
#   AT      (0, 0, 0) RELATIVE Monochromator_Arm
#   ROTATED (0, a2/2, 0) RELATIVE Monochromator_Arm
# mono_out_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# mono_out_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# mono_out_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# Monochromator_Out  Arm
#   AT      (0, 0, 0) RELATIVE Monochromator_Arm
#   ROTATED (0, a2, 0) RELATIVE Monochromator_Arm
# mono_out_rot_DEBUG  Monitor_nD
#   AT      (0, 0, 0.1) RELATIVE PREVIOUS
# mono_out_rot_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# mono_out_rot_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# before_sample_slit  Slit
#   AT      (0, 0, 1.75) RELATIVE Monochromator_Out
# sample_arm  Arm
#   AT      (0, 0, 2.0) RELATIVE Monochromator_Out
#   ROTATED (0, a3, 0) RELATIVE Monochromator_Out
# sample_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# sample_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# sample_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# 10T  Arm
#   AT      (0, 0, 0) RELATIVE sample_arm
# Al_inc  Incoherent_process
#   AT      (0, 0, 0) ABSOLUTE
# Al_pow  Powder_process
#   AT      (0, 0, 0) ABSOLUTE
# Al  Union_make_material
#   AT      (0, 0, 0) ABSOLUTE
# 10T_layer_0_layer  Union_cylinder
#   AT      (0, 0.0, 0) RELATIVE 10T
# 10T_layer_0_layer_vac  Union_cylinder
#   AT      (0, 0.0, 0) RELATIVE 10T
# 10T_layer_0_outer_cut_0  Union_cylinder
#   AT      (0, 0.0, 0) RELATIVE 10T
# 10T_layer_0_outer_cut_replace_0  Union_cylinder
#   AT      (0, 0.0, 0) RELATIVE 10T
# 10T_logger_space_zx  Union_logger_2D_space
#   AT      (0, 0, 0) RELATIVE 10T
# 10T_logger_space_zy  Union_logger_2D_space
#   AT      (0, 0, 0) RELATIVE 10T
# 10T_logger_space_xy  Union_logger_2D_space
#   AT      (0, 0, 0) RELATIVE 10T
# 10T_logger_space_zy_close  Union_logger_3D_space
#   AT      (0, 0, 0) RELATIVE 10T
# 10T_master  Union_master
#   AT      (0, 0, 0) ABSOLUTE
# v_sample  V_sample
#   AT      (0, 0, 0) RELATIVE 10T
#   ROTATED (0, a4, 0) RELATIVE 10T
# master_after_sample  Union_master
#   AT      (0, 0, 0) RELATIVE 10T
# Sample_Out  Arm
#   AT      (0, 0, 0) RELATIVE sample_arm
#   ROTATED (0, a4, 0) RELATIVE sample_arm
# sample_out_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# sample_out_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# sample_out_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# after_sample_slit  Slit
#   AT      (0, 0, 0.25) RELATIVE Sample_Out
# slit_B_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# slit_B_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# slit_B_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# Ana_Cradle  Arm
#   AT      (0, 0, 1.26) RELATIVE Sample_Out
# analyzer_IN_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# analyzer_IN_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# analyzer_IN_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# analyzer  Monochromator_curved
#   AT      (0, 0, 0) RELATIVE Ana_Cradle
#   ROTATED (0, a6*0.5, 0) RELATIVE Ana_Cradle
# Ana_Out  Arm
#   AT      (0, 0, 0) RELATIVE Ana_Cradle
#   ROTATED (0, a6, 0) RELATIVE Ana_Cradle
# slit  Slit
#   AT      (0, 0, 0.34) RELATIVE Ana_Out
# detector_DEBUG  Monitor_nD
#   AT      (0, 0, 0.64) RELATIVE PREVIOUS
# detector_psd_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# detector_psdcyl_DEBUG  Monitor_nD
#   AT      (0, 0, 0) RELATIVE PREVIOUS
# detector_all  Monitor
#   AT      (0, 0, 0.641) RELATIVE Ana_Out

# %%
import mcstasscript as ms

# %%
print(myinstrument)
#help(ms.Cryostat)
#help(ms.Layer)
# Out:
# ######## Instrument ThALES
# - Instrument: ThALES -
# Calculators:
# ThALES
# - ParametersCollection object -
#   Master Parameters
#   a2                                  79.1       [degree]
#   a3                                  0          [degree]
#   a4                                  60         [degree]
#   a6                                  74.34      [degree]
#
#    ThALES
#     - Parameters object -
#    a2                                  74.31657289464766 [degree]             Angle between beam reflected by monochromator and incident beam   L[33 degree, 128 degree]
#    a3                                  0          [degree]             sample table rotation angle
#    a4                                  60         [degree]             Angle between reflected by sample and incident beams   L[-128 degree, 128 degree]
#    a6                                  74.34      [degree]             Angle between reflected by analyzer and incident beams
#    monochromator_d                     3.355      [angstrom]           Monochromator lattice parameter
#    SAMPLE                              1
#    Ei                                  0          [millielectron_volt]  Initial neutron energy
#    dE                                  0          [millielectron_volt]  Initial neutron energy dispertion
#    lambda                              0          [angstrom]
#    dlambda                             0          [angstrom]
#
# ############

# %%
a6.energy = a2.energy
a4.value = 60 * ureg.degree
myThALES.calculator_base_dir = "/tmp/test/" 
data_empty = myThALES.backengine()
#myinstrument.run()
# Out:
# INFO: Using directory: "/tmp/test_2"
# INFO: Regenerating c-file: ThALES.c
# Warning: 'V_sample' is an obsolete component (not maintained).
# CFLAGS= -I@MCCODE_LIB@/share/
# INFO: Recompiling: ./ThALES.out
# mccode-r.c: In function ‘sighandler’:
# mccode-r.c:3719:5: warning: implicit declaration of function ‘kill’; did you mean ‘ceill’? [-Wimplicit-function-declaration]
# In file included from /usr/local/mcstas/2.7/tools/Python/mcrun/../mccodelib/../../../contrib/union/Incoherent_process.comp:65:
# /usr/local/mcstas/2.7/tools/Python/mcrun/../mccodelib/../../../share/Union_functions.c: In function ‘write_tagging_tree’:
# /usr/local/mcstas/2.7/tools/Python/mcrun/../mccodelib/../../../share/Union_functions.c:1599:105: warning: passing argument 4 of ‘qsort’ from incompatible pointer type [-Wincompatible-pointer-types]
#    qsort(total_history.saved_histories,total_history.used_elements,sizeof (struct saved_history_struct), Sample_compare_history_intensities);
#                                                                                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from mccode-r.h:42:
# /usr/include/stdlib.h:828:20: note: expected ‘__compar_fn_t’ {aka ‘int (*)(const void *, const void *)’} but argument is of type ‘int (*)(const struct saved_history_struct *, const struct saved_history_struct *)’
#       __compar_fn_t __compar) __nonnull ((1, 4));
#       ~~~~~~~~~~~~~~^~~~~~~~
# /usr/local/mcstas/2.7/tools/Python/mcrun/../mccodelib/../../../share/Union_functions.c:1608:20: warning: passing argument 1 of ‘printf_history’ from incompatible pointer type [-Wincompatible-pointer-types]
#      printf_history(&total_history.saved_histories[history_iterate]);
#                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# mccode-r.h:219:27: note: in definition of macro ‘MPI_MASTER’
# In file included from /usr/local/mcstas/2.7/tools/Python/mcrun/../mccodelib/../../../contrib/union/Incoherent_process.comp:65:
# /usr/local/mcstas/2.7/tools/Python/mcrun/../mccodelib/../../../share/Union_functions.c:1429:50: note: expected ‘struct dynamic_history_list *’ but argument is of type ‘struct saved_history_struct *’
#  void printf_history(struct dynamic_history_list *history) {
#                      ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~
# INFO: ===
# Component: H53_7 (Guide_tapering)
#            Height at the guide exit (h2): 0.120000
# Component: H53_7 (Guide_tapering)
#            Width at the guide exit (w2): 0.024856
# Warning: 7431 events were removed in Component[73] after_sample_slit=Slit()
#          (negative time, miss next components, rounding errors, Nan, Inf).
# Warning: No neutron could reach Component[84] detector_DEBUG
# Warning: No neutron could reach Component[85] detector_psd_DEBUG
# Warning: No neutron could reach Component[86] detector_psdcyl_DEBUG
# Warning: No neutron could reach Component[87] detector_all
# INFO: Placing instr file copy ThALES.instr in dataset /tmp/test_2
#
#           lambda: 4.05
# lambda: 4.05 +/- 0.04
# energy: 4.98 +/- 0.10
# [ThALES] Initialize
# Opening input file '/usr/local/mcstas/2.7/tools/Python/mcrun/../mccodelib/../../../data/supermirror_m3.rfl' (Table_Read_Offset)
# Monochromator_curved: component Monochromator Q=1.87 Angs-1 (DM=3.355 Angs)
#             horizontal: 13 blades focusing with RH=6.62 [m]
#             vertical:   13 blades focusing with RV=2.42 [m]
# Opening input file '/usr/local/mcstas/2.7/tools/Python/mcrun/../mccodelib/../../../data/Al.laz' (Table_Read_Offset)
# Table from file 'Al.laz' (block 1) is 26 x 18 (x=1:8), constant step. interpolation: linear
#   '# TITLE *Aluminum-Al-[FM3-M] Miller, H.P.jr.;DuMond, J.W.M.[1942] at 298 K; ...'
# PowderN: Al_pow: Reading 26 rows from Al.laz
# PowderN: Al_pow: Read 26 reflections from file 'Al.laz'
# PowderN: Al_pow: Vc=66.4 [Angs] sigma_abs=0.924 [barn] sigma_inc=0.0328 [barn] reflections=Al.laz
# Allocating 3D arrays
# ---------------------------------------------------------------------
# global_process_list.num_elements: 2
# name of process [0]: Al_inc
# component index [0]: 55
# name of process [1]: Al_pow
# component index [1]: 56
# ---------------------------------------------------------------------
# global_material_list.num_elements: 1
# name of material    [0]: Al
# component index     [0]: 57
# my_absoprtion       [0]: 1.391566
# number of processes [0]: 2
# ---------------------------------------------------------------------
# global_geometry_list.num_elements: 1
#
# name of geometry    [0]: 10T_layer_0_layer
# component index     [0]: 58
# Volume.name         [0]: 10T_layer_0_layer
# Volume.p_physics.is_vacuum           [0]: 0
# Volume.p_physics.my_absorption       [0]: 1.391566
# Volume.p_physics.number of processes [0]: 2
# Volume.geometry.shape                [0]: cylinder
# Volume.geometry.center.x             [0]: 1.925540
# Volume.geometry.center.y             [0]: 0.000000
# Volume.geometry.center.z             [0]: 22.848444
# Volume.geometry.rotation_matrix[0]           [0]: [0.270322 0.000000 -0.962770]
# Volume.geometry.rotation_matrix[1]           [0]: [-0.000000 1.000000 0.000000]
# Volume.geometry.rotation_matrix[2]           [0]: [0.962770 -0.000000 0.270322]
# Volume.geometry.geometry_parameters.cyl_radius [0]: 0.027400
# Volume.geometry.geometry_parameters.height [0]: 0.302000
# Volume.geometry.focus_data_array.elements[0].Aim             [0]: [0.000000 0.000000 1.000000]
#
# name of geometry    [1]: 10T_layer_0_layer_vac
# component index     [1]: 59
# Volume.name         [1]: 10T_layer_0_layer_vac
# Volume.p_physics.is_vacuum           [1]: 1
# Volume.p_physics.my_absorption       [1]: 0.000000
# Volume.p_physics.number of processes [1]: 0
# Volume.geometry.shape                [1]: cylinder
# Volume.geometry.center.x             [1]: 1.925540
# Volume.geometry.center.y             [1]: 0.000000
# Volume.geometry.center.z             [1]: 22.848444
# Volume.geometry.rotation_matrix[0]           [1]: [0.270322 0.000000 -0.962770]
# Volume.geometry.rotation_matrix[1]           [1]: [-0.000000 1.000000 0.000000]
# Volume.geometry.rotation_matrix[2]           [1]: [0.962770 -0.000000 0.270322]
# Volume.geometry.geometry_parameters.cyl_radius [1]: 0.025400
# Volume.geometry.geometry_parameters.height [1]: 0.300000
# Volume.geometry.focus_data_array.elements[0].Aim             [1]: [0.000000 0.000000 1.000000]
#
# name of geometry    [2]: 10T_layer_0_outer_cut_0
# component index     [2]: 60
# Volume.name         [2]: 10T_layer_0_outer_cut_0
# Volume.p_physics.is_vacuum           [2]: 1
# Volume.p_physics.my_absorption       [2]: 0.000000
# Volume.p_physics.number of processes [2]: 0
# Volume.geometry.shape                [2]: cylinder
# Volume.geometry.center.x             [2]: 1.925540
# Volume.geometry.center.y             [2]: 0.000000
# Volume.geometry.center.z             [2]: 22.848444
# Volume.geometry.rotation_matrix[0]           [2]: [0.270322 0.000000 -0.962770]
# Volume.geometry.rotation_matrix[1]           [2]: [-0.000000 1.000000 0.000000]
# Volume.geometry.rotation_matrix[2]           [2]: [0.962770 -0.000000 0.270322]
# Volume.geometry.geometry_parameters.cyl_radius [2]: 0.027401
# Volume.geometry.geometry_parameters.height [2]: 0.022001
# Volume.geometry.focus_data_array.elements[0].Aim             [2]: [0.000000 0.000000 1.000000]
#
# name of geometry    [3]: 10T_layer_0_outer_cut_replace_0
# component index     [3]: 61
# Volume.name         [3]: 10T_layer_0_outer_cut_replace_0
# Volume.p_physics.is_vacuum           [3]: 0
# Volume.p_physics.my_absorption       [3]: 1.391566
# Volume.p_physics.number of processes [3]: 2
# Volume.geometry.shape                [3]: cylinder
# Volume.geometry.center.x             [3]: 1.925540
# Volume.geometry.center.y             [3]: 0.000000
# Volume.geometry.center.z             [3]: 22.848444
# Volume.geometry.rotation_matrix[0]           [3]: [0.270322 0.000000 -0.962770]
# Volume.geometry.rotation_matrix[1]           [3]: [-0.000000 1.000000 0.000000]
# Volume.geometry.rotation_matrix[2]           [3]: [0.962770 -0.000000 0.270322]
# Volume.geometry.geometry_parameters.cyl_radius [3]: 0.026400
# Volume.geometry.geometry_parameters.height [3]: 0.022005
# Volume.geometry.focus_data_array.elements[0].Aim             [3]: [0.000000 0.000000 1.000000]
# ---------------------------------------------------------------------
# number_of_volumes = 5
# number_of_masks = 0
# number_of_masked_volumes = 0
#
#  ---- Overview of the lists generated for each volume ----
# List overview for surrounding vacuum
# LIST: Children for Volume                  0 = [1,2,3,4]
# LIST: Direct_children for Volume           0 = [1,3]
# LIST: Intersect_check_list for Volume      0 = [1,3]
# LIST: Mask_intersect_list for Volume       0 = []
# LIST: Destinations_list for Volume         0 = []
# LIST: Reduced_destinations_list for Volume 0 = []
# LIST: Next_volume_list for Volume          0 = [1,3]
# LIST: mask_list for Volume                 0 = []
# LIST: masked_by_list for Volume            0 = []
# LIST: masked_by_mask_index_list for Volume 0 = []
#       mask_mode for Volume                 0 = 0
#
# List overview for 10T_layer_0_layer with cylinder shape made of Al
# LIST: Children for Volume                  1 = [2,4]
# LIST: Direct_children for Volume           1 = [2,4]
# LIST: Intersect_check_list for Volume      1 = [2,3,4]
# LIST: Mask_intersect_list for Volume       1 = []
# LIST: Destinations_list for Volume         1 = [0]
# LIST: Reduced_destinations_list for Volume 1 = []
# LIST: Next_volume_list for Volume          1 = [0,2,3,4]
#       Is_vacuum for Volume                 1 = 0
#       is_mask_volume for Volume            1 = 0
#       is_masked_volume for Volume          1 = 0
#       is_exit_volume for Volume            1 = 0
# LIST: mask_list for Volume                 1 = []
# LIST: masked_by_list for Volume            1 = []
# LIST: masked_by_mask_index_list for Volume 1 = []
#       mask_mode for Volume                 1 = 0
#
# List overview for 10T_layer_0_layer_vac with cylinder shape made of Vacuum
# LIST: Children for Volume                  2 = []
# LIST: Direct_children for Volume           2 = []
# LIST: Intersect_check_list for Volume      2 = []
# LIST: Mask_intersect_list for Volume       2 = []
# LIST: Destinations_list for Volume         2 = [1,3,4]
# LIST: Reduced_destinations_list for Volume 2 = [1,3]
# LIST: Next_volume_list for Volume          2 = [1,3,4]
#       Is_vacuum for Volume                 2 = 1
#       is_mask_volume for Volume            2 = 0
#       is_masked_volume for Volume          2 = 0
#       is_exit_volume for Volume            2 = 0
# LIST: mask_list for Volume                 2 = []
# LIST: masked_by_list for Volume            2 = []
# LIST: masked_by_mask_index_list for Volume 2 = []
#       mask_mode for Volume                 2 = 0
#
# List overview for 10T_layer_0_outer_cut_0 with cylinder shape made of Vacuum
# LIST: Children for Volume                  3 = []
# LIST: Direct_children for Volume           3 = []
# LIST: Intersect_check_list for Volume      3 = [2,4]
# LIST: Mask_intersect_list for Volume       3 = []
# LIST: Destinations_list for Volume         3 = [0,1]
# LIST: Reduced_destinations_list for Volume 3 = [1]
# LIST: Next_volume_list for Volume          3 = [0,1,2,4]
#       Is_vacuum for Volume                 3 = 1
#       is_mask_volume for Volume            3 = 0
#       is_masked_volume for Volume          3 = 0
#       is_exit_volume for Volume            3 = 0
# LIST: mask_list for Volume                 3 = []
# LIST: masked_by_list for Volume            3 = []
# LIST: masked_by_mask_index_list for Volume 3 = []
#       mask_mode for Volume                 3 = 0
#
# List overview for 10T_layer_0_outer_cut_replace_0 with cylinder shape made of Al
# LIST: Children for Volume                  4 = []
# LIST: Direct_children for Volume           4 = []
# LIST: Intersect_check_list for Volume      4 = [2]
# LIST: Mask_intersect_list for Volume       4 = []
# LIST: Destinations_list for Volume         4 = [1,3]
# LIST: Reduced_destinations_list for Volume 4 = [1,3]
# LIST: Next_volume_list for Volume          4 = [1,3,2]
#       Is_vacuum for Volume                 4 = 0
#       is_mask_volume for Volume            4 = 0
#       is_masked_volume for Volume          4 = 0
#       is_exit_volume for Volume            4 = 0
# LIST: mask_list for Volume                 4 = []
# LIST: masked_by_list for Volume            4 = []
# LIST: masked_by_mask_index_list for Volume 4 = []
#       mask_mode for Volume                 4 = 0
#
# Union_master component 10T_master initialized sucessfully
# ---------------------------------------------------------------------
# global_process_list.num_elements: 2
# name of process [0]: Al_inc
# component index [0]: 55
# name of process [1]: Al_pow
# component index [1]: 56
# ---------------------------------------------------------------------
# global_material_list.num_elements: 1
# name of material    [0]: Al
# component index     [0]: 57
# my_absoprtion       [0]: 1.391566
# number of processes [0]: 2
# ---------------------------------------------------------------------
# global_geometry_list.num_elements: 1
#
# name of geometry    [0]: 10T_layer_0_layer
# component index     [0]: 58
# Volume.name         [0]: 10T_layer_0_layer
# Volume.p_physics.is_vacuum           [0]: 0
# Volume.p_physics.my_absorption       [0]: 1.391566
# Volume.p_physics.number of processes [0]: 2
# Volume.geometry.shape                [0]: cylinder
# Volume.geometry.center.x             [0]: 1.925540
# Volume.geometry.center.y             [0]: 0.000000
# Volume.geometry.center.z             [0]: 22.848444
# Volume.geometry.rotation_matrix[0]           [0]: [0.270322 0.000000 -0.962770]
# Volume.geometry.rotation_matrix[1]           [0]: [-0.000000 1.000000 0.000000]
# Volume.geometry.rotation_matrix[2]           [0]: [0.962770 -0.000000 0.270322]
# Volume.geometry.geometry_parameters.cyl_radius [0]: 0.027400
# Volume.geometry.geometry_parameters.height [0]: 0.302000
# Volume.geometry.focus_data_array.elements[0].Aim             [0]: [0.962770 0.000000 0.270322]
#
# name of geometry    [1]: 10T_layer_0_layer_vac
# component index     [1]: 59
# Volume.name         [1]: 10T_layer_0_layer_vac
# Volume.p_physics.is_vacuum           [1]: 1
# Volume.p_physics.my_absorption       [1]: 0.000000
# Volume.p_physics.number of processes [1]: 0
# Volume.geometry.shape                [1]: cylinder
# Volume.geometry.center.x             [1]: 1.925540
# Volume.geometry.center.y             [1]: 0.000000
# Volume.geometry.center.z             [1]: 22.848444
# Volume.geometry.rotation_matrix[0]           [1]: [0.270322 0.000000 -0.962770]
# Volume.geometry.rotation_matrix[1]           [1]: [-0.000000 1.000000 0.000000]
# Volume.geometry.rotation_matrix[2]           [1]: [0.962770 -0.000000 0.270322]
# Volume.geometry.geometry_parameters.cyl_radius [1]: 0.025400
# Volume.geometry.geometry_parameters.height [1]: 0.300000
# Volume.geometry.focus_data_array.elements[0].Aim             [1]: [0.962770 0.000000 0.270322]
#
# name of geometry    [2]: 10T_layer_0_outer_cut_0
# component index     [2]: 60
# Volume.name         [2]: 10T_layer_0_outer_cut_0
# Volume.p_physics.is_vacuum           [2]: 1
# Volume.p_physics.my_absorption       [2]: 0.000000
# Volume.p_physics.number of processes [2]: 0
# Volume.geometry.shape                [2]: cylinder
# Volume.geometry.center.x             [2]: 1.925540
# Volume.geometry.center.y             [2]: 0.000000
# Volume.geometry.center.z             [2]: 22.848444
# Volume.geometry.rotation_matrix[0]           [2]: [0.270322 0.000000 -0.962770]
# Volume.geometry.rotation_matrix[1]           [2]: [-0.000000 1.000000 0.000000]
# Volume.geometry.rotation_matrix[2]           [2]: [0.962770 -0.000000 0.270322]
# Volume.geometry.geometry_parameters.cyl_radius [2]: 0.027401
# Volume.geometry.geometry_parameters.height [2]: 0.022001
# Volume.geometry.focus_data_array.elements[0].Aim             [2]: [0.962770 0.000000 0.270322]
#
# name of geometry    [3]: 10T_layer_0_outer_cut_replace_0
# component index     [3]: 61
# Volume.name         [3]: 10T_layer_0_outer_cut_replace_0
# Volume.p_physics.is_vacuum           [3]: 0
# Volume.p_physics.my_absorption       [3]: 1.391566
# Volume.p_physics.number of processes [3]: 2
# Volume.geometry.shape                [3]: cylinder
# Volume.geometry.center.x             [3]: 1.925540
# Volume.geometry.center.y             [3]: 0.000000
# Volume.geometry.center.z             [3]: 22.848444
# Volume.geometry.rotation_matrix[0]           [3]: [0.270322 0.000000 -0.962770]
# Volume.geometry.rotation_matrix[1]           [3]: [-0.000000 1.000000 0.000000]
# Volume.geometry.rotation_matrix[2]           [3]: [0.962770 -0.000000 0.270322]
# Volume.geometry.geometry_parameters.cyl_radius [3]: 0.026400
# Volume.geometry.geometry_parameters.height [3]: 0.022005
# Volume.geometry.focus_data_array.elements[0].Aim             [3]: [0.962770 0.000000 0.270322]
# ---------------------------------------------------------------------
# number_of_volumes = 5
# number_of_masks = 0
# number_of_masked_volumes = 0
#
#  ---- Overview of the lists generated for each volume ----
# List overview for surrounding vacuum
# LIST: Children for Volume                  0 = [1,2,3,4]
# LIST: Direct_children for Volume           0 = [1,3]
# LIST: Intersect_check_list for Volume      0 = [1,3]
# LIST: Mask_intersect_list for Volume       0 = []
# LIST: Destinations_list for Volume         0 = []
# LIST: Reduced_destinations_list for Volume 0 = []
# LIST: Next_volume_list for Volume          0 = [1,3]
# LIST: mask_list for Volume                 0 = []
# LIST: masked_by_list for Volume            0 = []
# LIST: masked_by_mask_index_list for Volume 0 = []
#       mask_mode for Volume                 0 = 0
#
# List overview for 10T_layer_0_layer with cylinder shape made of Al
# LIST: Children for Volume                  1 = [2,4]
# LIST: Direct_children for Volume           1 = [2,4]
# LIST: Intersect_check_list for Volume      1 = [2,3,4]
# LIST: Mask_intersect_list for Volume       1 = []
# LIST: Destinations_list for Volume         1 = [0]
# LIST: Reduced_destinations_list for Volume 1 = []
# LIST: Next_volume_list for Volume          1 = [0,2,3,4]
#       Is_vacuum for Volume                 1 = 0
#       is_mask_volume for Volume            1 = 0
#       is_masked_volume for Volume          1 = 0
#       is_exit_volume for Volume            1 = 0
# LIST: mask_list for Volume                 1 = []
# LIST: masked_by_list for Volume            1 = []
# LIST: masked_by_mask_index_list for Volume 1 = []
#       mask_mode for Volume                 1 = 0
#
# List overview for 10T_layer_0_layer_vac with cylinder shape made of Vacuum
# LIST: Children for Volume                  2 = []
# LIST: Direct_children for Volume           2 = []
# LIST: Intersect_check_list for Volume      2 = []
# LIST: Mask_intersect_list for Volume       2 = []
# LIST: Destinations_list for Volume         2 = [1,3,4]
# LIST: Reduced_destinations_list for Volume 2 = [1,3]
# LIST: Next_volume_list for Volume          2 = [1,3,4]
#       Is_vacuum for Volume                 2 = 1
#       is_mask_volume for Volume            2 = 0
#       is_masked_volume for Volume          2 = 0
#       is_exit_volume for Volume            2 = 0
# LIST: mask_list for Volume                 2 = []
# LIST: masked_by_list for Volume            2 = []
# LIST: masked_by_mask_index_list for Volume 2 = []
#       mask_mode for Volume                 2 = 0
#
# List overview for 10T_layer_0_outer_cut_0 with cylinder shape made of Vacuum
# LIST: Children for Volume                  3 = []
# LIST: Direct_children for Volume           3 = []
# LIST: Intersect_check_list for Volume      3 = [2,4]
# LIST: Mask_intersect_list for Volume       3 = []
# LIST: Destinations_list for Volume         3 = [0,1]
# LIST: Reduced_destinations_list for Volume 3 = [1]
# LIST: Next_volume_list for Volume          3 = [0,1,2,4]
#       Is_vacuum for Volume                 3 = 1
#       is_mask_volume for Volume            3 = 0
#       is_masked_volume for Volume          3 = 0
#       is_exit_volume for Volume            3 = 0
# LIST: mask_list for Volume                 3 = []
# LIST: masked_by_list for Volume            3 = []
# LIST: masked_by_mask_index_list for Volume 3 = []
#       mask_mode for Volume                 3 = 0
#
# List overview for 10T_layer_0_outer_cut_replace_0 with cylinder shape made of Al
# LIST: Children for Volume                  4 = []
# LIST: Direct_children for Volume           4 = []
# LIST: Intersect_check_list for Volume      4 = [2]
# LIST: Mask_intersect_list for Volume       4 = []
# LIST: Destinations_list for Volume         4 = [1,3]
# LIST: Reduced_destinations_list for Volume 4 = [1,3]
# LIST: Next_volume_list for Volume          4 = [1,3,2]
#       Is_vacuum for Volume                 4 = 0
#       is_mask_volume for Volume            4 = 0
#       is_masked_volume for Volume          4 = 0
#       is_exit_volume for Volume            4 = 0
# LIST: mask_list for Volume                 4 = []
# LIST: masked_by_list for Volume            4 = []
# LIST: masked_by_mask_index_list for Volume 4 = []
#       mask_mode for Volume                 4 = 0
#
# Union_master component master_after_sample initialized sucessfully
#
# Trace ETA 48 [s] % 22 30 40 50 60 70 80 90
# Save [ThALES]
# Detector: H5_DEBUG_I=7.99894e+11 H5_DEBUG_ERR=2.52949e+08 H5_DEBUG_N=1e+07 "H5_DEBUG.E"
# Detector: H5_DEBUG_I=7.99894e+11 H5_DEBUG_ERR=2.52949e+08 H5_DEBUG_N=1e+07 "H5_DEBUG.x"
# Detector: H5_DEBUG_I=7.99894e+11 H5_DEBUG_ERR=2.52949e+08 H5_DEBUG_N=1e+07 "H5_DEBUG.y"
# Detector: H5_psd_DEBUG_I=7.99894e+11 H5_psd_DEBUG_ERR=2.52949e+08 H5_psd_DEBUG_N=1e+07 "H5_DEBUG.x_y"
# Detector: H5_psdcyl_DEBUG_I=7.95749e+11 H5_psdcyl_DEBUG_ERR=2.52297e+08 H5_psdcyl_DEBUG_N=9.94787e+06 "H5_DEBUG.th_y"
# Detector: H5_1a_DEBUG_I=3.93599e+11 H5_1a_DEBUG_ERR=1.75689e+08 H5_1a_DEBUG_N=5.54409e+06 "H5_1a_DEBUG.E"
# Detector: H5_1a_DEBUG_I=3.93599e+11 H5_1a_DEBUG_ERR=1.75689e+08 H5_1a_DEBUG_N=5.54409e+06 "H5_1a_DEBUG.x"
# Detector: H5_1a_DEBUG_I=3.93599e+11 H5_1a_DEBUG_ERR=1.75689e+08 H5_1a_DEBUG_N=5.54409e+06 "H5_1a_DEBUG.y"
# Detector: H5_1a_psd_DEBUG_I=3.93599e+11 H5_1a_psd_DEBUG_ERR=1.75689e+08 H5_1a_psd_DEBUG_N=5.54409e+06 "H5_1a_DEBUG.x_y"
# Detector: H5_1a_psdcyl_DEBUG_I=3.93587e+11 H5_1a_psdcyl_DEBUG_ERR=1.75687e+08 H5_1a_psdcyl_DEBUG_N=5.54395e+06 "H5_1a_DEBUG.th_y"
# Detector: H5_1b_DEBUG_I=2.14093e+11 H5_1b_DEBUG_ERR=1.24907e+08 H5_1b_DEBUG_N=3.9916e+06 "H5_1b_DEBUG.E"
# Detector: H5_1b_DEBUG_I=2.14093e+11 H5_1b_DEBUG_ERR=1.24907e+08 H5_1b_DEBUG_N=3.9916e+06 "H5_1b_DEBUG.x"
# Detector: H5_1b_DEBUG_I=2.14093e+11 H5_1b_DEBUG_ERR=1.24907e+08 H5_1b_DEBUG_N=3.9916e+06 "H5_1b_DEBUG.y"
# Detector: H5_1b_psd_DEBUG_I=2.14093e+11 H5_1b_psd_DEBUG_ERR=1.24907e+08 H5_1b_psd_DEBUG_N=3.9916e+06 "H5_1b_DEBUG.x_y"
# Detector: H5_1b_psdcyl_DEBUG_I=2.14093e+11 H5_1b_psdcyl_DEBUG_ERR=1.24907e+08 H5_1b_psdcyl_DEBUG_N=3.9916e+06 "H5_1b_DEBUG.th_y"
# Detector: H53_D_DEBUG_I=1.28309e+11 H53_D_DEBUG_ERR=8.78268e+07 H53_D_DEBUG_N=3.58381e+06 "H53_D_DEBUG.E"
# Detector: H53_D_DEBUG_I=1.28309e+11 H53_D_DEBUG_ERR=8.78268e+07 H53_D_DEBUG_N=3.58381e+06 "H53_D_DEBUG.x"
# Detector: H53_D_DEBUG_I=1.28309e+11 H53_D_DEBUG_ERR=8.78268e+07 H53_D_DEBUG_N=3.58381e+06 "H53_D_DEBUG.y"
# Detector: H53_D_psd_DEBUG_I=1.28309e+11 H53_D_psd_DEBUG_ERR=8.78268e+07 H53_D_psd_DEBUG_N=3.58381e+06 "H53_D_DEBUG.x_y"
# Detector: H53_D_psdcyl_DEBUG_I=1.28309e+11 H53_D_psdcyl_DEBUG_ERR=8.78268e+07 H53_D_psdcyl_DEBUG_N=3.58381e+06 "H53_D_DEBUG.th_y"
# Detector: H53_7_DEBUG_I=8.17163e+10 H53_7_DEBUG_ERR=7.07087e+07 H53_7_DEBUG_N=2.49382e+06 "H53_7_DEBUG.E"
# Detector: H53_7_DEBUG_I=8.17163e+10 H53_7_DEBUG_ERR=7.07087e+07 H53_7_DEBUG_N=2.49382e+06 "H53_7_DEBUG.x"
# Detector: H53_7_DEBUG_I=8.17163e+10 H53_7_DEBUG_ERR=7.07087e+07 H53_7_DEBUG_N=2.49382e+06 "H53_7_DEBUG.y"
# Detector: H53_7_psd_DEBUG_I=8.17163e+10 H53_7_psd_DEBUG_ERR=7.07087e+07 H53_7_psd_DEBUG_N=2.49382e+06 "H53_7_DEBUG.x_y"
# Detector: H53_7_psdcyl_DEBUG_I=8.17163e+10 H53_7_psdcyl_DEBUG_ERR=7.07087e+07 H53_7_psdcyl_DEBUG_N=2.49382e+06 "H53_7_DEBUG.th_y"
# Detector: slit_A_DEBUG_I=7.95561e+10 slit_A_DEBUG_ERR=6.98257e+07 slit_A_DEBUG_N=2.33502e+06 "slit_A_DEBUG.E"
# Detector: slit_A_DEBUG_I=7.95561e+10 slit_A_DEBUG_ERR=6.98257e+07 slit_A_DEBUG_N=2.33502e+06 "slit_A_DEBUG.x"
# Detector: slit_A_DEBUG_I=7.95561e+10 slit_A_DEBUG_ERR=6.98257e+07 slit_A_DEBUG_N=2.33502e+06 "slit_A_DEBUG.y"
# Detector: slit_A_psd_DEBUG_I=7.95561e+10 slit_A_psd_DEBUG_ERR=6.98257e+07 slit_A_psd_DEBUG_N=2.33502e+06 "slit_A_DEBUG.x_y"
# Detector: slit_A_psdcyl_DEBUG_I=7.95561e+10 slit_A_psdcyl_DEBUG_ERR=6.98257e+07 slit_A_psdcyl_DEBUG_N=2.33502e+06 "slit_A_DEBUG.th_y"
# Detector: mono_in_DEBUG_I=5.52651e+10 mono_in_DEBUG_ERR=6.00777e+07 mono_in_DEBUG_N=1.04774e+06 "mono_in_DEBUG.E"
# Detector: mono_in_DEBUG_I=5.52651e+10 mono_in_DEBUG_ERR=6.00777e+07 mono_in_DEBUG_N=1.04774e+06 "mono_in_DEBUG.x"
# Detector: mono_in_DEBUG_I=5.52651e+10 mono_in_DEBUG_ERR=6.00777e+07 mono_in_DEBUG_N=1.04774e+06 "mono_in_DEBUG.y"
# Detector: mono_in_psd_DEBUG_I=5.52651e+10 mono_in_psd_DEBUG_ERR=6.00777e+07 mono_in_psd_DEBUG_N=1.04774e+06 "mono_in_DEBUG.x_y"
# Detector: mono_in_psdcyl_DEBUG_I=7.41738e+10 mono_in_psdcyl_DEBUG_ERR=6.77568e+07 mono_in_psdcyl_DEBUG_N=2.05784e+06 "mono_in_DEBUG.th_y"
# Detector: mono_out_DEBUG_I=9.27419e+09 mono_out_DEBUG_ERR=2.48779e+07 mono_out_DEBUG_N=171303 "mono_out_DEBUG.E"
# Detector: mono_out_DEBUG_I=9.27419e+09 mono_out_DEBUG_ERR=2.48779e+07 mono_out_DEBUG_N=171303 "mono_out_DEBUG.x"
# Detector: mono_out_DEBUG_I=9.27419e+09 mono_out_DEBUG_ERR=2.48779e+07 mono_out_DEBUG_N=171303 "mono_out_DEBUG.y"
# Detector: mono_out_psd_DEBUG_I=9.27419e+09 mono_out_psd_DEBUG_ERR=2.48779e+07 mono_out_psd_DEBUG_N=171303 "mono_out_DEBUG.x_y"
# Detector: mono_out_psdcyl_DEBUG_I=2.73446e+10 mono_out_psdcyl_DEBUG_ERR=4.10977e+07 mono_out_psdcyl_DEBUG_N=1.03929e+06 "mono_out_DEBUG.th_y"
# Detector: mono_out_rot_DEBUG_I=1.85498e+10 mono_out_rot_DEBUG_ERR=3.46811e+07 mono_out_rot_DEBUG_N=555817 "mono_out_rot_DEBUG.E"
# Detector: mono_out_rot_DEBUG_I=1.85498e+10 mono_out_rot_DEBUG_ERR=3.46811e+07 mono_out_rot_DEBUG_N=555817 "mono_out_rot_DEBUG.x"
# Detector: mono_out_rot_DEBUG_I=1.85498e+10 mono_out_rot_DEBUG_ERR=3.46811e+07 mono_out_rot_DEBUG_N=555817 "mono_out_rot_DEBUG.y"
# Detector: mono_out_rot_psd_DEBUG_I=1.85498e+10 mono_out_rot_psd_DEBUG_ERR=3.46811e+07 mono_out_rot_psd_DEBUG_N=555817 "mono_out_rot_DEBUG.x_y"
# Detector: mono_out_rot_psdcyl_DEBUG_I=2.75668e+10 mono_out_rot_psdcyl_DEBUG_ERR=4.12467e+07 mono_out_rot_psdcyl_DEBUG_N=1.04346e+06 "mono_out_rot_DEBUG.th_y"
# Detector: sample_DEBUG_I=3.3815e+09 sample_DEBUG_ERR=1.58342e+07 sample_DEBUG_N=46085 "sample_DEBUG.E"
# Detector: sample_DEBUG_I=3.3815e+09 sample_DEBUG_ERR=1.58342e+07 sample_DEBUG_N=46085 "sample_DEBUG.x"
# Detector: sample_DEBUG_I=3.3815e+09 sample_DEBUG_ERR=1.58342e+07 sample_DEBUG_N=46085 "sample_DEBUG.y"
# Detector: sample_psd_DEBUG_I=3.3815e+09 sample_psd_DEBUG_ERR=1.58342e+07 sample_psd_DEBUG_N=46085 "sample_DEBUG.x_y"
# Detector: sample_psdcyl_DEBUG_I=3.3815e+09 sample_psdcyl_DEBUG_ERR=1.58342e+07 sample_psdcyl_DEBUG_N=46085 "sample_DEBUG.th_y"
# Detector: 10T_logger_space_zx_I=6.7549e+07 10T_logger_space_zx_ERR=575849 10T_logger_space_zx_N=22870 "10T_space_zx.dat"
# Detector: 10T_logger_space_zy_I=6.7549e+07 10T_logger_space_zy_ERR=575849 10T_logger_space_zy_N=22870 "10T_space_zy.dat"
# Detector: 10T_logger_space_xy_I=6.7549e+07 10T_logger_space_xy_ERR=575849 10T_logger_space_xy_N=22870 "10T_space_xy.dat"
# Detector: 10T_logger_space_zy_close_I=58226.4 10T_logger_space_zy_close_ERR=7846 10T_logger_space_zy_close_N=125 "10T_space_zy_close.dat_0"
# Detector: sample_out_DEBUG_I=1.70331e+08 sample_out_DEBUG_ERR=4.35908e+06 sample_out_DEBUG_N=3004 "sample_out_DEBUG.E"
# Detector: sample_out_DEBUG_I=1.70331e+08 sample_out_DEBUG_ERR=4.35908e+06 sample_out_DEBUG_N=3004 "sample_out_DEBUG.x"
# Detector: sample_out_DEBUG_I=1.70331e+08 sample_out_DEBUG_ERR=4.35908e+06 sample_out_DEBUG_N=3004 "sample_out_DEBUG.y"
# Detector: sample_out_psd_DEBUG_I=1.70331e+08 sample_out_psd_DEBUG_ERR=4.35908e+06 sample_out_psd_DEBUG_N=3004 "sample_out_DEBUG.x_y"
# Detector: sample_out_psdcyl_DEBUG_I=1.055e+09 sample_out_psdcyl_DEBUG_ERR=1.07719e+07 sample_out_psdcyl_DEBUG_N=16990 "sample_out_DEBUG.th_y"
# Detector: slit_B_DEBUG_I=2047.91 slit_B_DEBUG_ERR=1171.74 slit_B_DEBUG_N=8 "slit_B_DEBUG.E"
# Detector: slit_B_DEBUG_I=2047.91 slit_B_DEBUG_ERR=1171.74 slit_B_DEBUG_N=8 "slit_B_DEBUG.x"
# Detector: slit_B_DEBUG_I=2047.91 slit_B_DEBUG_ERR=1171.74 slit_B_DEBUG_N=8 "slit_B_DEBUG.y"
# Detector: slit_B_psd_DEBUG_I=2047.91 slit_B_psd_DEBUG_ERR=1171.74 slit_B_psd_DEBUG_N=8 "slit_B_DEBUG.x_y"
# Detector: slit_B_psdcyl_DEBUG_I=2047.91 slit_B_psdcyl_DEBUG_ERR=1171.74 slit_B_psdcyl_DEBUG_N=8 "slit_B_DEBUG.th_y"
# Detector: analyzer_IN_DEBUG_I=219.439 analyzer_IN_DEBUG_ERR=219.439 analyzer_IN_DEBUG_N=1 "analyzer_IN_DEBUG.E"
# Detector: analyzer_IN_DEBUG_I=219.439 analyzer_IN_DEBUG_ERR=219.439 analyzer_IN_DEBUG_N=1 "analyzer_IN_DEBUG.x"
# Detector: analyzer_IN_DEBUG_I=219.439 analyzer_IN_DEBUG_ERR=219.439 analyzer_IN_DEBUG_N=1 "analyzer_IN_DEBUG.y"
# Detector: analyzer_IN_psd_DEBUG_I=219.439 analyzer_IN_psd_DEBUG_ERR=219.439 analyzer_IN_psd_DEBUG_N=1 "analyzer_IN_DEBUG.x_y"
# Detector: analyzer_IN_psdcyl_DEBUG_I=1918.65 analyzer_IN_psdcyl_DEBUG_ERR=1176.52 analyzer_IN_psdcyl_DEBUG_N=6 "analyzer_IN_DEBUG.th_y"
# Detector: detector_DEBUG_I=0 detector_DEBUG_ERR=0 detector_DEBUG_N=0 "detector_DEBUG.E"
# Detector: detector_DEBUG_I=0 detector_DEBUG_ERR=0 detector_DEBUG_N=0 "detector_DEBUG.x"
# Detector: detector_DEBUG_I=0 detector_DEBUG_ERR=0 detector_DEBUG_N=0 "detector_DEBUG.y"
# Detector: detector_psd_DEBUG_I=0 detector_psd_DEBUG_ERR=0 detector_psd_DEBUG_N=0 "detector_DEBUG.x_y"
# Detector: detector_psdcyl_DEBUG_I=0 detector_psdcyl_DEBUG_ERR=0 detector_psdcyl_DEBUG_N=0 "detector_DEBUG.th_y"
# Detector: detector_all_I=0 detector_all_ERR=0 detector_all_N=0 "detector_all"
#
# Finally [ThALES: /tmp/test_2]. Time: 48 [s]
#
# The component named "detector_all" had no data file and will not be loaded.

# %%
ms.name_plot_options("10T_logger_space_zx", data_empty, log=True, orders_of_mag=4)
ms.name_plot_options("10T_logger_space_zy", data_empty, log=True, orders_of_mag=4)

# %%
#print(data_empty)
for d in data_empty:
  ms.make_sub_plot(d)
# Out:
# Plotting data with name H5_DEBUG
# Plotting data with name H5_DEBUG
# Plotting data with name H5_DEBUG
# Plotting data with name H5_psd_DEBUG
# Plotting data with name H5_psdcyl_DEBUG
# Plotting data with name H5_1a_DEBUG
# Plotting data with name H5_1a_DEBUG
# Plotting data with name H5_1a_DEBUG
# Plotting data with name H5_1a_psd_DEBUG
# Plotting data with name H5_1a_psdcyl_DEBUG
# Plotting data with name H5_1b_DEBUG
# Plotting data with name H5_1b_DEBUG
# Plotting data with name H5_1b_DEBUG
# Plotting data with name H5_1b_psd_DEBUG
# Plotting data with name H5_1b_psdcyl_DEBUG
# Plotting data with name H53_D_DEBUG
# Plotting data with name H53_D_DEBUG
# Plotting data with name H53_D_DEBUG
# Plotting data with name H53_D_psd_DEBUG
# Plotting data with name H53_D_psdcyl_DEBUG
# Plotting data with name H53_7_DEBUG
# Plotting data with name H53_7_DEBUG
# Plotting data with name H53_7_DEBUG
# Plotting data with name H53_7_psd_DEBUG
# Plotting data with name H53_7_psdcyl_DEBUG
# Plotting data with name slit_A_DEBUG
# Plotting data with name slit_A_DEBUG
# Plotting data with name slit_A_DEBUG
# Plotting data with name slit_A_psd_DEBUG
# Plotting data with name slit_A_psdcyl_DEBUG
# Plotting data with name mono_in_DEBUG
# Plotting data with name mono_in_DEBUG
# Plotting data with name mono_in_DEBUG
# Plotting data with name mono_in_psd_DEBUG
# Plotting data with name mono_in_psdcyl_DEBUG
# Plotting data with name mono_out_DEBUG
# Plotting data with name mono_out_DEBUG
# Plotting data with name mono_out_DEBUG
# Plotting data with name mono_out_psd_DEBUG
# Plotting data with name mono_out_psdcyl_DEBUG
# Plotting data with name mono_out_rot_DEBUG
# Plotting data with name mono_out_rot_DEBUG
# Plotting data with name mono_out_rot_DEBUG
# Plotting data with name mono_out_rot_psd_DEBUG
# Plotting data with name mono_out_rot_psdcyl_DEBUG
# Plotting data with name sample_DEBUG
# Plotting data with name sample_DEBUG
# Plotting data with name sample_DEBUG
# Plotting data with name sample_psd_DEBUG
# Plotting data with name sample_psdcyl_DEBUG
# Plotting data with name 10T_logger_space_zx
# Plotting data with name 10T_logger_space_zy
# Plotting data with name 10T_logger_space_xy
# Plotting data with name 10T_logger_space_zy_close
# Plotting data with name sample_out_DEBUG
# Plotting data with name sample_out_DEBUG
# Plotting data with name sample_out_DEBUG
# Plotting data with name sample_out_psd_DEBUG
# Plotting data with name sample_out_psdcyl_DEBUG
# Plotting data with name slit_B_DEBUG
# Plotting data with name slit_B_DEBUG
# Plotting data with name slit_B_DEBUG
# Plotting data with name slit_B_psd_DEBUG
# Plotting data with name slit_B_psdcyl_DEBUG
# Plotting data with name analyzer_IN_DEBUG
# Plotting data with name analyzer_IN_DEBUG
# Plotting data with name analyzer_IN_DEBUG
# Plotting data with name analyzer_IN_psd_DEBUG
# Plotting data with name analyzer_IN_psdcyl_DEBUG
# Plotting data with name detector_DEBUG
# Plotting data with name detector_DEBUG
# Plotting data with name detector_DEBUG
# Plotting data with name detector_psd_DEBUG
# Plotting data with name detector_psdcyl_DEBUG

# %%
ms.make_sub_plot(data_empty[48:54])
#ms.make_sub_plot(data_empty[2])
# Out:
# Plotting data with name sample_psd_DEBUG
# Plotting data with name sample_psdcyl_DEBUG
# Plotting data with name 10T_logger_space_zx
# Plotting data with name 10T_logger_space_zy
# Plotting data with name 10T_logger_space_xy
# Plotting data with name 10T_logger_space_zy_close

# %%
ms.make_sub_plot(data_empty[55:59])
# Out:
# Plotting data with name sample_out_DEBUG
# Plotting data with name sample_out_DEBUG
# Plotting data with name sample_out_psd_DEBUG
# Plotting data with name sample_out_psdcyl_DEBUG
